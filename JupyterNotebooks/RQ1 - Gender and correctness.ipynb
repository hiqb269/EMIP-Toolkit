# %% [markdown]
# # RQ1 - Is gender a significant predictor of code comprehension accuracy in the EMIP dataset, after controlling for programming expertise and task effects?

# %% [markdown]
# RQ1 examines whether gender is associated with code-comprehension accuracy after adjusting for self-reported programming expertise and task effects. It also asks whether any observed raw gender difference is consistent with a skill-gap account, where differences in prior programming experience could partly explain performance differences.

# %% [markdown]
# **In the EMIP study gender  is available as a between-subjects factor and task (Rectangle vs. Vehicle) as a within-subjects factor. Each participant completed both comprehension tasks, resulting in repeated measures. Task order was counterbalanced across participants as shown in GEE section.**

# %% [markdown]
# # Mount and import

# %%
from google.colab import drive
drive.mount("/content/drive", force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import sys
sys.path.append('/content/drive/MyDrive/EMIP-Toolkit')

# %%
import os
import pandas as pd
import numpy as np

# %% [markdown]
# #Load metadata

# %% [markdown]
# Load metadata

# %%
desired_path = os.path.join(
    '/content/drive/MyDrive/EMIP-Toolkit/emtk/datasets/EMIP',
    'EMIP-Toolkit- replication package',
    'emip_dataset'
)

os.chdir(desired_path)

# %%
from collections import Counter
METADATA_FILE = 'emip_metadata.csv'
try:
    metadata_df = pd.read_csv(METADATA_FILE)
    print(f"Loaded metadata for {len(metadata_df)} participants")

except FileNotFoundError:
    print(f"Warning: Metadata file '{METADATA_FILE}' not found")
except Exception as e:
    print(f"Error loading metadata: {e}.")
# Out:
# Loaded metadata for 216 participants

# %%
metadata_df.head()
# Out:
#    id  age  gender mother_tongue english_level visual_aid makeup  \
# 0   1   63    male         Czech          high    glasses     no
# 1   2   24    male        Slovak        medium    glasses     no
# 2   3   27  female        Hebrew          high         no     no
# 3   4   24    male         Hindi          high    glasses     no
# 4   5   24    male       Italian        medium         no     no
#
#   experiment_language expertise_experiment_language  time_experiment_language  \
# 0                Java                          high                      30.0
# 1                Java                        medium                       2.0
# 2                Java                          none                       0.0
# 3                Java                        medium                       4.0
# 4                Java                          none                       0.0
#
#    ... order_rectangle   stimulus_rectangle  \
# 0  ...               2   rectangle_java.jpg
# 1  ...               1  rectangle_java2.jpg
# 2  ...               2  rectangle_java2.jpg
# 3  ...               1  rectangle_java2.jpg
# 4  ...               1  rectangle_java2.jpg
#
#                                       answer_vehicle correct_vehicle  \
# 0  ... defines a vehicle by a producer, that has ...               0
# 1  ... defines a vehicle by a producer, that has ...               0
# 2  ... defines a vehicle by a producer, that has ...               0
# 3  ... defines a vehicle by a producer, that has ...               0
# 4  ... defines a vehicle by a producer, that has ...               0
#
#   order_vehicle   stimulus_vehicle  mother_tongue_original  \
# 0             1   vehicle_java.jpg                   czech
# 1             2  vehicle_java2.jpg                  Slovak
# 2             1  vehicle_java2.jpg                  Hebrew
# 3             2  vehicle_java2.jpg                   Hindi
# 4             2  vehicle_java2.jpg                italiano
#
#    time_experiment_language_original time_programming_original  \
# 0                                30y                       40+
# 1                                  2                         5
# 2                                  0                         0
# 3                                  4                        10
# 4                                  0                         5
#
#                             other_languages_original
# 0  CoffeeScript (high) JavaScript (high) Python (...
# 1                 c++(low), php(medium), delphi(low)
# 2                                           c# (low)
# 3  Python(High) C++(High) C(High) HTML/PHP/SQL (H...
# 4                                   objective C , C
#
# [5 rows x 27 columns]

# %% [markdown]
# # Expertise versus gender

# %%
metadata_df['time_programming'] = pd.to_numeric(metadata_df['time_programming'], errors='coerce')
metadata_df['time_programming'] = metadata_df['time_programming'].fillna(40.0)

# %%
#find all lines in metadata_df where expertise_experiment_language and expertise_programming are dififerent
metadata_df[metadata_df['expertise_experiment_language'] != metadata_df['expertise_programming']]
# Out:
#       id  age  gender     mother_tongue english_level      visual_aid makeup  \
# 4      5   24    male           Italian        medium              no     no
# 7      8   26  female           Italian          high              no    yes
# 8      9   38    male            German          high              no     no
# 9     10   32    male        Portuguese          high              no     no
# 10    11   34    male           English          high         glasses     no
# ..   ...  ...     ...               ...           ...             ...    ...
# 205  206   30    male   English; Hebrew          high              no     no
# 208  209   78  female           English          high  contact lenses     no
# 209  210   31    male            Slovak          high              no     no
# 210  211   21  female  Italian; English          high              no    yes
# 212  213   26    male             Hindi          high              no     no
#
#     experiment_language expertise_experiment_language  \
# 4                  Java                          none
# 7                  Java                          none
# 8                  Java                           low
# 9                  Java                           low
# 10                 Java                        medium
# ..                  ...                           ...
# 205                Java                        medium
# 208                Java                        medium
# 209                Java                        medium
# 210                Java                          none
# 212                Java                           low
#
#      time_experiment_language  ... order_rectangle   stimulus_rectangle  \
# 4                         0.0  ...               1  rectangle_java2.jpg
# 7                         0.0  ...               2  rectangle_java2.jpg
# 8                        14.0  ...               1  rectangle_java2.jpg
# 9                         0.0  ...               1   rectangle_java.jpg
# 10                        5.0  ...               2   rectangle_java.jpg
# ..                        ...  ...             ...                  ...
# 205                       1.0  ...               2  rectangle_java2.jpg
# 208                       5.0  ...               2   rectangle_java.jpg
# 209                       0.0  ...               2  rectangle_java2.jpg
# 210                       0.0  ...               1  rectangle_java2.jpg
# 212                       0.5  ...               1  rectangle_java2.jpg
#
#                                         answer_vehicle  correct_vehicle  \
# 4    ... defines a vehicle by a producer, that has ...                0
# 7    ... defines a vehicle by a producer, that has ...                0
# 8    .... defines a vehicle by a producer, that has...                1
# 9    ... defines a vehicle by a producer, that has ...                0
# 10   ... defines a vehicle by a producer, that has ...                0
# ..                                                 ...              ...
# 205  ... defines a vehicle by a producer, that has ...                0
# 208  ... defines a vehicle by a producer, that has ...                0
# 209  ... defines a vehicle by a producer, that has ...                0
# 210  ... defines a vehicle by a producer, that has ...                0
# 212                                      I'm not sure.                0
#
#     order_vehicle   stimulus_vehicle  mother_tongue_original  \
# 4               2  vehicle_java2.jpg                italiano
# 7               1  vehicle_java2.jpg                 Italian
# 8               2  vehicle_java2.jpg                  german
# 9               2   vehicle_java.jpg              Portuguese
# 10              1   vehicle_java.jpg                 English
# ..            ...                ...                     ...
# 205             1  vehicle_java2.jpg           english & heb
# 208             1   vehicle_java.jpg                 English
# 209             1  vehicle_java2.jpg                  Slovak
# 210             2  vehicle_java2.jpg        Italian, English
# 212             2  vehicle_java2.jpg                   Hindi
#
#      time_experiment_language_original time_programming_original  \
# 4                                    0                         5
# 7                                    0                         1
# 8                                   14                        14
# 9                             2 months                   5 years
# 10                                   5                        16
# ..                                 ...                       ...
# 205                                 1                          1
# 208                                  5                        56
# 209                                  0                        18
# 210                                  0                         1
# 212                           6 months                   3 years
#
#                               other_languages_original
# 4                                     objective C , C
# 7                                            C++ (low)
# 8    c++ high python low bash high haskell low asse...
# 9    C(high), C++(high), VB(medium), Pascal (medium...
# 10   PHP (high) Python (low) Ruby (low) Assembly (l...
# ..                                                 ...
# 205                                  java Script (low)
# 208  Algol (medium), PL1(high),Fortran (high), C (h...
# 209                                C (high) C# (high)
# 210                                          C, medium
# 212     Python(medium) VBA(High) Excel(High) C(medium)
#
# [79 rows x 27 columns]

# %%
expertise_counts_p = metadata_df.groupby(['gender', 'expertise_programming']).size().reset_index(name='count')
#add a column percentage to expertise_counts_p that calculates the percentage of count i.e. count/41 for female and count/175 for male
expertise_counts_p['percentage'] = expertise_counts_p['count'] / expertise_counts_p.groupby('gender')['count'].transform('sum')
print("Expertise counts by programming language expertise:")
print(expertise_counts_p)
# Out:
# Expertise counts by programming language expertise:
#    gender expertise_programming  count  percentage
# 0  female                  high      4    0.097561
# 1  female                   low     13    0.317073
# 2  female                medium     18    0.439024
# 3  female                  none      6    0.146341
# 4    male                  high     36    0.205714
# 5    male                   low     32    0.182857
# 6    male                medium    102    0.582857
# 7    male                  none      5    0.028571

# %%
expertise_counts = metadata_df.groupby(['gender', 'expertise_experiment_language']).size().reset_index(name='count')
print("Expertise counts by gender and experimental language expertise:")
print(expertise_counts)
# Out:
# Expertise counts by gender and experimental language expertise:
#    gender expertise_experiment_language  count
# 0  female                          high      2
# 1  female                           low     11
# 2  female                        medium     14
# 3  female                          none     14
# 4    male                          high     15
# 5    male                           low     58
# 6    male                        medium     86
# 7    male                          none     16

# %%
expertise_percentages = metadata_df.groupby('gender')['expertise_experiment_language'].value_counts(normalize=True).mul(100).unstack(fill_value=0)
print("Expertise percentages by gender and experimental language expertise:")
print(expertise_percentages)
# Out:
# Expertise percentages by gender and experimental language expertise:
# expertise_experiment_language      high        low     medium       none
# gender
# female                         4.878049  26.829268  34.146341  34.146341
# male                           8.571429  33.142857  49.142857   9.142857

# %%
expertise_percentages_p = metadata_df.groupby('gender')['expertise_programming'].value_counts(normalize=True).mul(100).unstack(fill_value=0)
print("Expertise percentages by gender and programming expertise:")
print(expertise_percentages_p)
# Out:
# Expertise percentages by gender and programming expertise:
# expertise_programming       high        low     medium       none
# gender
# female                  9.756098  31.707317  43.902439  14.634146
# male                   20.571429  18.285714  58.285714   2.857143

# %% [markdown]
# # Metrics of correctness by gender

# %% [markdown]
# **Correct answer for rectangle**

# %%
metadata_df["correct_rectangle"].value_counts()
# Out:
# correct_rectangle
# 1    152
# 0     64
# Name: count, dtype: int64

# %%
metadata_df.groupby("gender")["correct_rectangle"].value_counts()
# Out:
# gender  correct_rectangle
# female  1                     29
#         0                     12
# male    1                    123
#         0                     52
# Name: count, dtype: int64

# %% [markdown]
# **Percentage of correct answers by gender - Rectangle**

# %%
# Calculate the percentage of correct answers for the 'correct_vehicle' column by gender
gender_rec_correct_percentage = metadata_df.groupby('gender')['correct_rectangle'].value_counts(normalize=True).mul(100).unstack()

display("Percentage of correct rectangle answers by gender:")
display(gender_rec_correct_percentage)
# Out:
# 'Percentage of correct rectangle answers by gender:'
# correct_rectangle          0          1
# gender
# female             29.268293  70.731707
# male               29.714286  70.285714

# %% [markdown]
# **Correct answer for Vehicle**

# %%
metadata_df["correct_vehicle"].value_counts()
# Out:
# correct_vehicle
# 0    166
# 1     50
# Name: count, dtype: int64

# %%
metadata_df.groupby("gender")["correct_vehicle"].value_counts()
# Out:
# gender  correct_vehicle
# female  0                   35
#         1                    6
# male    0                  131
#         1                   44
# Name: count, dtype: int64

# %% [markdown]
# **Percentage of correct answers by gender - Vehicle**

# %%
# Calculate the percentage of correct answers for the 'correct_vehicle' column by gender
gender_vehicle_correct_percentage = metadata_df.groupby('gender')['correct_vehicle'].value_counts(normalize=True).mul(100).unstack()

print("Percentage of correct vehicle answers by gender:")
display(gender_vehicle_correct_percentage)
# Out:
# Percentage of correct vehicle answers by gender:
# correct_vehicle          0          1
# gender
# female           85.365854  14.634146
# male             74.857143  25.142857

# %% [markdown]
# # Correct answers distribution

# %% [markdown]
# The binary outcomes of the code comprehension questions, both rectangle and vehicle have been collapsed into a total score in this section, with 0 indicating the participant got no answer correct, 1 indicating the participant got one answer correct and 2 indicating the participant got both answers correct.

# %%
participant_data = metadata_df[['id', 'gender', 'expertise_programming', 'expertise_experiment_language', 'time_programming']].copy()
participant_data['total_score'] = metadata_df['correct_rectangle'] + metadata_df['correct_vehicle']

display(participant_data)
# Out:
#       id  gender expertise_programming expertise_experiment_language  \
# 0      1    male                  high                          high
# 1      2    male                medium                        medium
# 2      3  female                  none                          none
# 3      4    male                medium                        medium
# 4      5    male                   low                          none
# ..   ...     ...                   ...                           ...
# 211  212    male                medium                        medium
# 212  213    male                medium                           low
# 213  214    male                medium                        medium
# 214  215    male                medium                        medium
# 215  216  female                  none                          none
#
#      time_programming  total_score
# 0                40.0            1
# 1                 5.0            0
# 2                 0.0            1
# 3                10.0            1
# 4                 5.0            1
# ..                ...          ...
# 211               3.0            1
# 212               3.0            0
# 213               4.0            2
# 214               2.0            1
# 215               0.0            1
#
# [216 rows x 6 columns]

# %%
# Convert time_programming to numeric and recode non-numeric 40+ value as 40.0.
participant_data['time_programming'] = pd.to_numeric(participant_data['time_programming'], errors='coerce')
participant_data['time_programming'] = participant_data['time_programming'].fillna(40.0)
# Add is_experienced: 1 if time_programming is greater than or equal to 4 years, otherwise 0.
participant_data['is_experienced'] = np.where(participant_data['time_programming'] >= 4, 1, 0)
display(participant_data)
# Out:
#       id  gender expertise_programming expertise_experiment_language  \
# 0      1    male                  high                          high
# 1      2    male                medium                        medium
# 2      3  female                  none                          none
# 3      4    male                medium                        medium
# 4      5    male                   low                          none
# ..   ...     ...                   ...                           ...
# 211  212    male                medium                        medium
# 212  213    male                medium                           low
# 213  214    male                medium                        medium
# 214  215    male                medium                        medium
# 215  216  female                  none                          none
#
#      time_programming  total_score  is_experienced
# 0                40.0            1               1
# 1                 5.0            0               1
# 2                 0.0            1               0
# 3                10.0            1               1
# 4                 5.0            1               1
# ..                ...          ...             ...
# 211               3.0            1               0
# 212               3.0            0               0
# 213               4.0            2               1
# 214               2.0            1               0
# 215               0.0            1               0
#
# [216 rows x 7 columns]

# %%
#from participant_data find the females who have a total score of 2
female_correct_both = participant_data[(participant_data['gender'] == 'female') & (participant_data['total_score'] == 2)]
display(female_correct_both)
# Out:
#       id  gender expertise_programming expertise_experiment_language  \
# 18    19  female                medium                        medium
# 94    95  female                medium                          none
# 149  150  female                medium                        medium
# 179  180  female                   low                           low
#
#      time_programming  total_score  is_experienced
# 18                3.0            2               0
# 94                5.0            2               1
# 149              10.0            2               1
# 179               2.0            2               0

# %%
female_correct_none = participant_data[(participant_data['gender'] == 'female') & (participant_data['total_score'] == 0)]
display(female_correct_none)
# Out:
#       id  gender expertise_programming expertise_experiment_language  \
# 11    12  female                   low                          none
# 35    36  female                  none                          none
# 64    65  female                   low                           low
# 75    76  female                  high                          high
# 92    93  female                  none                          none
# 102  103  female                   low                           low
# 106  107  female                medium                           low
# 147  148  female                  high                        medium
# 180  181  female                  none                          none
# 203  204  female                   low                          none
#
#      time_programming  total_score  is_experienced
# 11                4.0            0               1
# 35                0.0            0               0
# 64                1.0            0               0
# 75                4.0            0               1
# 92                0.0            0               0
# 102               1.0            0               0
# 106               3.0            0               0
# 147               2.0            0               0
# 180               0.0            0               0
# 203               0.5            0               0

# %%
# Calculate percentages of total scores by gender
score_percentages = participant_data.groupby('gender')['total_score'].value_counts(normalize=True).mul(100).rename('percentage').reset_index()
display(score_percentages)
# Out:
#    gender  total_score  percentage
# 0  female            1   65.853659
# 1  female            0   24.390244
# 2  female            2    9.756098
# 3    male            1   60.000000
# 4    male            0   22.285714
# 5    male            2   17.714286

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
colors = {

        'male': '#4C78A8',    # muted blue
        'female': '#F28E2B'   # muted orange

}

# %%
plt.figure(figsize=(8, 6))
sns.barplot(x='total_score', y='percentage', hue='gender', data=score_percentages, palette=colors)
plt.title('Percentage Distribution of Total Scores by Gender')
plt.xlabel('Total Score (correct_rectangle + correct_vehicle)')
plt.ylabel('Percentage of Participants')
plt.xticks(ticks=[0, 1, 2], labels=['0', '1', '2'])
plt.legend(title='Gender')
plt.show()

# %%
# Ensure expertise_programming has a defined order for better visualization
expertise_order = ['none', 'low', 'medium', 'high']
participant_data['expertise_programming'] = pd.Categorical(participant_data['expertise_programming'], categories=expertise_order, ordered=True)

# Calculate percentages of total scores by gender and expertise_programming
# Use observed=False to suppress FutureWarning about categorical columns if desired
detailed_score_percentages = participant_data.groupby(['gender', 'expertise_programming', 'total_score'], observed=False).size().reset_index(name='count')

# Corrected line using .transform() to get percentages that align with the original DataFrame's index
detailed_score_percentages['percentage'] = detailed_score_percentages.groupby(['gender', 'expertise_programming'], observed=False)['count'].transform(lambda x: 100 * x / x.sum())

# The following line is redundant as detailed_score_percentages already has a flat index
# detailed_score_percentages = detailed_score_percentages.reset_index()

# Create the bar plot using catplot for faceting
g = sns.catplot(
    data=detailed_score_percentages,
    x='total_score',
    y='percentage',
    hue='gender',
    col='expertise_programming',
    col_wrap=2, # Wrap columns after 2 plots
    kind='bar',
    palette=colors,
    height=4, aspect=1.2,
    col_order=expertise_order # Ensure order of expertise is maintained for 'col' facet
)

g.set_axis_labels('Total Score', 'Percentage of Participants')
g.set_titles('Expertise: {col_name}')
g.fig.suptitle('Percentage Distribution of Total Scores by Gender and Programming Expertise', y=1.02) # Adjust suptitle position
plt.tight_layout(rect=[0, 0.03, 1, 0.98]) # Adjust layout to prevent suptitle overlap
# Move legend
g._legend.remove()  # Remove the default legend
g.fig.legend(loc='upper center', bbox_to_anchor=(1, 1.05), ncol=2, title='Gender')
plt.tight_layout(rect=[0, 0.03, 1, 0.95])  # Adjust to make room at top
plt.show()

# %%
 display(detailed_score_percentages)
# Out:
#     gender expertise_programming  total_score  count  percentage
# 0   female                  none            0      3   50.000000
# 1   female                  none            1      3   50.000000
# 2   female                  none            2      0    0.000000
# 3   female                   low            0      4   30.769231
# 4   female                   low            1      8   61.538462
# 5   female                   low            2      1    7.692308
# 6   female                medium            0      1    5.555556
# 7   female                medium            1     14   77.777778
# 8   female                medium            2      3   16.666667
# 9   female                  high            0      2   50.000000
# 10  female                  high            1      2   50.000000
# 11  female                  high            2      0    0.000000
# 12    male                  none            0      4   80.000000
# 13    male                  none            1      1   20.000000
# 14    male                  none            2      0    0.000000
# 15    male                   low            0      9   28.125000
# 16    male                   low            1     18   56.250000
# 17    male                   low            2      5   15.625000
# 18    male                medium            0     22   21.568627
# 19    male                medium            1     63   61.764706
# 20    male                medium            2     17   16.666667
# 21    male                  high            0      4   11.111111
# 22    male                  high            1     23   63.888889
# 23    male                  high            2      9   25.000000

# %%
expertise_order = ['none', 'low', 'medium', 'high']
participant_data['expertise_experiment_language'] = pd.Categorical(participant_data['expertise_experiment_language'], categories=expertise_order, ordered=True)

# Calculate percentages of total scores by gender and expertise_programming
# Use observed=False to suppress FutureWarning about categorical columns if desired
detailed_score_percentages = participant_data.groupby(['gender', 'expertise_experiment_language', 'total_score'], observed=False).size().reset_index(name='count')

# Corrected line using .transform() to get percentages that align with the original DataFrame's index
detailed_score_percentages['percentage'] = detailed_score_percentages.groupby(['gender', 'expertise_experiment_language'], observed=False)['count'].transform(lambda x: 100 * x / x.sum())

# The following line is redundant as detailed_score_percentages already has a flat index
# detailed_score_percentages = detailed_score_percentages.reset_index()

# Create the bar plot using catplot for faceting
g = sns.catplot(
    data=detailed_score_percentages,
    x='total_score',
    y='percentage',
    hue='gender',
    col='expertise_experiment_language',
    col_wrap=2, # Wrap columns after 2 plots
    kind='bar',
    palette=colors,
    height=4, aspect=1.2,
    col_order=expertise_order # Ensure order of expertise is maintained for 'col' facet
)

g.set_axis_labels('Total Score', 'Percentage of Participants')
g.set_titles('Expertise: {col_name}')
g.fig.suptitle('Percentage Distribution of Total Scores by Gender and Expertise in Experiment Language', y=1.02) # Adjust suptitle position
plt.tight_layout(rect=[0, 0.03, 1, 0.98]) # Adjust layout to prevent suptitle overlap
# Move legend
g._legend.remove()  # Remove the default legend
g.fig.legend(loc='upper center', bbox_to_anchor=(1, 1.05), ncol=2, title='Gender')
plt.tight_layout(rect=[0, 0.03, 1, 0.95])  # Adjust to make room at top
plt.show()

# %%
display(detailed_score_percentages)
# Out:
#     gender expertise_experiment_language  total_score  count  percentage
# 0   female                          none            0      5   35.714286
# 1   female                          none            1      8   57.142857
# 2   female                          none            2      1    7.142857
# 3   female                           low            0      3   27.272727
# 4   female                           low            1      7   63.636364
# 5   female                           low            2      1    9.090909
# 6   female                        medium            0      1    7.142857
# 7   female                        medium            1     11   78.571429
# 8   female                        medium            2      2   14.285714
# 9   female                          high            0      1   50.000000
# 10  female                          high            1      1   50.000000
# 11  female                          high            2      0    0.000000
# 12    male                          none            0      6   37.500000
# 13    male                          none            1     10   62.500000
# 14    male                          none            2      0    0.000000
# 15    male                           low            0     15   25.862069
# 16    male                           low            1     31   53.448276
# 17    male                           low            2     12   20.689655
# 18    male                        medium            0     15   17.441860
# 19    male                        medium            1     55   63.953488
# 20    male                        medium            2     16   18.604651
# 21    male                          high            0      3   20.000000
# 22    male                          high            1      9   60.000000
# 23    male                          high            2      3   20.000000

# %%
# Ensure is_experienced is treated as a categorical variable for better visualization
participant_data['is_experienced'] = participant_data['is_experienced'].astype('category')

# Calculate percentages of total scores by gender and is_experienced
detailed_score_percentages_exp = participant_data.groupby(['gender', 'is_experienced', 'total_score'], observed=False).size().reset_index(name='count')
detailed_score_percentages_exp['percentage'] = detailed_score_percentages_exp.groupby(['gender', 'is_experienced'], observed=False)['count'].transform(lambda x: 100 * x / x.sum())
display(detailed_score_percentages_exp)
# Out:
#     gender is_experienced  total_score  count  percentage
# 0   female              0            0      8   30.769231
# 1   female              0            1     16   61.538462
# 2   female              0            2      2    7.692308
# 3   female              1            0      2   13.333333
# 4   female              1            1     11   73.333333
# 5   female              1            2      2   13.333333
# 6     male              0            0     23   27.710843
# 7     male              0            1     48   57.831325
# 8     male              0            2     12   14.457831
# 9     male              1            0     16   17.391304
# 10    male              1            1     57   61.956522
# 11    male              1            2     19   20.652174

# %%
# Create the bar plot using catplot for faceting by is_experienced
g = sns.catplot(
    data=detailed_score_percentages_exp,
    x='total_score',
    y='percentage',
    hue='gender',
    col='is_experienced',
    kind='bar',
    palette=colors,
    height=4, aspect=1.2
)

g.set_axis_labels('Total Score', 'Percentage of Participants')
g.set_titles('Is Experienced: {col_name}')
g.fig.suptitle('Percentage Distribution of Total Scores by Gender and Experience Level (With four or more years of programming experience)', y=1.02) # Adjust suptitle position
plt.tight_layout(rect=[0, 0.03, 1, 0.98]) # Adjust layout to prevent suptitle overlap

# Move legend
g._legend.remove()  # Remove the default legend
g.fig.legend(loc='upper center', bbox_to_anchor=(0.5, 0.93), ncol=2, title='Gender')
plt.tight_layout(rect=[0, 0.03, 1, 0.95])  # Adjust to make room at top
plt.show()

# %% [markdown]
# # Chi-square test

# %% [markdown]
# A chi-square test of independence was conducted separately for each task as an unadjusted descriptive check of the association between gender and correctness. These per-task tests use one response per participant, so they do not have the repeated-measures problem that would arise from pooling both task responses into a single 432-row table. However, they do not adjust for programming expertise, task difficulty, or task order, and they do not model the paired structure of the two task responses jointly. Therefore, the chi-square results are treated as exploratory, and the GEE logistic model is used for the main adjusted inference.

# %%
from scipy.stats import chi2_contingency

# %%
# Chi-square test for correct_rectangle and gender
contingency_table_rectangle = pd.crosstab(metadata_df['gender'], metadata_df['correct_rectangle'])
print (contingency_table_rectangle)
chi2_stat_rectangle, p_value_rectangle, dof_rectangle, expected_rectangle = chi2_contingency(contingency_table_rectangle)

print("Chi-square test for Correct Rectangle and Gender:")
print(f"Chi-square statistic: {chi2_stat_rectangle:.4f}")
print(f"P-value: {p_value_rectangle:.4f}")
print(f"Degrees of freedom: {dof_rectangle}")
print("Expected frequencies:")
print(expected_rectangle)

# Interpretation for rectangle
alpha = 0.05
if p_value_rectangle < alpha:
    print("\nResult for Correct Rectangle: Reject the null hypothesis. There is a statistically significant relationship between gender and correct rectangle answers.")
else:
    print("\nResult for Correct Rectangle: Fail to reject the null hypothesis. There is no statistically significant relationship between gender and correct rectangle answers.")
# Out:
# correct_rectangle   0    1
# gender
# female             12   29
# male               52  123
# Chi-square test for Correct Rectangle and Gender:
# Chi-square statistic: 0.0000
# P-value: 1.0000
# Degrees of freedom: 1
# Expected frequencies:
# [[ 12.14814815  28.85185185]
#  [ 51.85185185 123.14814815]]
#
# Result for Correct Rectangle: Fail to reject the null hypothesis. There is no statistically significant relationship between gender and correct rectangle answers.

# %%
# Chi-square test for correct_vehicle and gender
contingency_table_vehicle = pd.crosstab(metadata_df['gender'], metadata_df['correct_vehicle'])
chi2_stat_vehicle, p_value_vehicle, dof_vehicle, expected_vehicle = chi2_contingency(contingency_table_vehicle)
print (contingency_table_vehicle)
print("Chi-square test for Correct Vehicle and Gender:")
print(f"Chi-square statistic: {chi2_stat_vehicle:.4f}")
print(f"P-value: {p_value_vehicle:.4f}")
print(f"Degrees of freedom: {dof_vehicle}")
print("Expected frequencies:")
print(expected_vehicle)

# Interpretation for vehicle
alpha = 0.05
if p_value_vehicle < alpha:
    print("\nResult for Correct Vehicle: Reject the null hypothesis. There is a statistically significant relationship between gender and correct vehicle answers.")
else:
    print("\nResult for Correct Vehicle: Fail to reject the null hypothesis. There is no statistically significant relationship between gender and correct vehicle answers.")
# Out:
# correct_vehicle    0   1
# gender
# female            35   6
# male             131  44
# Chi-square test for Correct Vehicle and Gender:
# Chi-square statistic: 1.5136
# P-value: 0.2186
# Degrees of freedom: 1
# Expected frequencies:
# [[ 31.50925926   9.49074074]
#  [134.49074074  40.50925926]]
#
# Result for Correct Vehicle: Fail to reject the null hypothesis. There is no statistically significant relationship between gender and correct vehicle answers.

# %% [markdown]
# Initial per-task chi-square tests showed no significant unadjusted association between gender and correctness. However, these tests do not account for expertise, task difficulty, task order, or the paired structure of the two responses from each participant.

# %% [markdown]
# Why the chi-square tests are exploratory
#
# A separate 2 x 2 chi-square test for each task is acceptable as a simple per-task descriptive comparison because each table contains one response per participant. The limitation is that these tests are unadjusted: they cannot simultaneously control for programming expertise, task difficulty, task order, or other covariates.
#
# A single pooled chi-square test over all 432 task responses would be inappropriate because it would treat two responses from the same participant as independent observations. The GEE model is therefore preferred for the main analysis because it models the binary task-level outcome while accounting for within-participant clustering.

# %% [markdown]
# # **GEE**

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf
from statsmodels.genmod.generalized_estimating_equations import GEE
from statsmodels.genmod.families import Binomial
from statsmodels.genmod.cov_struct import Exchangeable
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
def infer_order(row):
    if pd.notna(row.get('order_vehicle')) and row['order_vehicle'] == 1:
        return 'vehicle_first'
    if pd.notna(row.get('order_rectangle')) and row['order_rectangle'] == 1:
        return 'rectangle_first'
    return np.nan

metadata_df['order'] = metadata_df.apply(infer_order, axis=1)

# %%
metadata_df['order'] = metadata_df['order'].astype('category')
metadata_df['order_bin'] = (metadata_df['order'] == 'vehicle_first').astype(int)

# Check balance by gender and other covariates
print(pd.crosstab(metadata_df['order'], metadata_df['gender']))
print(metadata_df['order'].value_counts(dropna=False))
# Out:
# gender           female  male
# order
# rectangle_first      20    85
# vehicle_first        21    90
# order
# vehicle_first      111
# rectangle_first    105
# Name: count, dtype: int64

# %%
display(metadata_df)
# Out:
#       id  age  gender mother_tongue english_level visual_aid makeup  \
# 0      1   63    male         Czech          high    glasses     no
# 1      2   24    male        Slovak        medium    glasses     no
# 2      3   27  female        Hebrew          high         no     no
# 3      4   24    male         Hindi          high    glasses     no
# 4      5   24    male       Italian        medium         no     no
# ..   ...  ...     ...           ...           ...        ...    ...
# 211  212   21    male        Slovak          high    glasses     no
# 212  213   26    male         Hindi          high         no     no
# 213  214   21    male        Slovak          high         no     no
# 214  215   22    male        Slovak        medium         no     no
# 215  216   22  female          Thai          high    glasses     no
#
#     experiment_language expertise_experiment_language  \
# 0                  Java                          high
# 1                  Java                        medium
# 2                  Java                          none
# 3                  Java                        medium
# 4                  Java                          none
# ..                  ...                           ...
# 211                Java                        medium
# 212                Java                           low
# 213                Java                        medium
# 214                Java                        medium
# 215                Java                          none
#
#      time_experiment_language  ...  \
# 0                        30.0  ...
# 1                         2.0  ...
# 2                         0.0  ...
# 3                         4.0  ...
# 4                         0.0  ...
# ..                        ...  ...
# 211                       2.0  ...
# 212                       0.5  ...
# 213                       1.0  ...
# 214                       1.0  ...
# 215                       0.0  ...
#
#                                         answer_vehicle correct_vehicle  \
# 0    ... defines a vehicle by a producer, that has ...               0
# 1    ... defines a vehicle by a producer, that has ...               0
# 2    ... defines a vehicle by a producer, that has ...               0
# 3    ... defines a vehicle by a producer, that has ...               0
# 4    ... defines a vehicle by a producer, that has ...               0
# ..                                                 ...             ...
# 211  .... defines a vehicle by a producer, that has...               1
# 212                                      I'm not sure.               0
# 213  .... defines a vehicle by a producer, that has...               1
# 214  .... defines a vehicle by a producer, that has...               1
# 215  ... defines a vehicle by a producer, that has ...               0
#
#     order_vehicle   stimulus_vehicle mother_tongue_original  \
# 0               1   vehicle_java.jpg                  czech
# 1               2  vehicle_java2.jpg                 Slovak
# 2               1  vehicle_java2.jpg                 Hebrew
# 3               2  vehicle_java2.jpg                  Hindi
# 4               2  vehicle_java2.jpg               italiano
# ..            ...                ...                    ...
# 211             2  vehicle_java2.jpg                 slovak
# 212             2  vehicle_java2.jpg                  Hindi
# 213             2  vehicle_java2.jpg                Slovak
# 214             1  vehicle_java2.jpg                 slovak
# 215             1  vehicle_java2.jpg                   Thai
#
#     time_experiment_language_original  time_programming_original  \
# 0                                 30y                        40+
# 1                                   2                          5
# 2                                   0                          0
# 3                                   4                         10
# 4                                   0                          5
# ..                                ...                        ...
# 211                                 2                          3
# 212                          6 months                    3 years
# 213                                 1                          4
# 214                                 1                          2
# 215                           6 weeks                    6 weeks
#
#                               other_languages_original            order  \
# 0    CoffeeScript (high) JavaScript (high) Python (...    vehicle_first
# 1                   c++(low), php(medium), delphi(low)  rectangle_first
# 2                                             c# (low)    vehicle_first
# 3    Python(High) C++(High) C(High) HTML/PHP/SQL (H...  rectangle_first
# 4                                     objective C , C   rectangle_first
# ..                                                 ...              ...
# 211                                C (high), C++ (low)  rectangle_first
# 212     Python(medium) VBA(High) Excel(High) C(medium)  rectangle_first
# 213                  C (medium) , JavaScript (medium)   rectangle_first
# 214               C (medium) c# (medium) Java (medium)    vehicle_first
# 215                                                Low    vehicle_first
#
#     order_bin
# 0           1
# 1           0
# 2           1
# 3           0
# 4           0
# ..        ...
# 211         0
# 212         0
# 213         0
# 214         1
# 215         1
#
# [216 rows x 29 columns]

# %% [markdown]
# **Task presentation order was counterbalanced across participants, with 105 participants viewing Rectangle first and 111 viewing Vehicle first. The proportion of female participants was nearly identical across order conditions (20 vs 21), indicating that order was not confounded with gender.**

# %%
# Reshape to long format: one row per participant-task
long = pd.melt(
    metadata_df,
    id_vars=['id','gender','order','expertise_programming','expertise_experiment_language','time_programming','english_level'],
    value_vars=['correct_rectangle','correct_vehicle'],
    var_name='task',
    value_name='correct'
)

# Clean task names and set rectangle as baseline
long['task'] = long['task'].str.replace('correct_','')
long['task'] = pd.Categorical(long['task'], categories=['rectangle','vehicle'])

# Binary outcome
long['correct'] = long['correct'].astype(int)

# Encode gender: female = 1, male = 0
long['gender_bin'] = (long['gender'] == 'female').astype(int)

# Map expertise_programming (example mapping; adjust if your labels differ)
exp_map = {'none':0, 'low':1, 'medium':2, 'high':3}
long['expertise_programming_num'] = long['expertise_programming'].map(exp_map)

# Map expertise_experiment_language
long['expertise_experiment_num'] = long['expertise_experiment_language'].map(exp_map)

# Map English level as high = 1 and non-high (medium or low) = 0.
# Low English proficiency is combined with medium because only four participants reported low proficiency.
long['english_bin'] = (long['english_level'] == 'high').astype(int)

# %% [markdown]
# Task order was modeled as a trial‑level variable indicating whether the specific task was presented first or second. This approach captures learning or fatigue effects. A participant‑level order variable (e.g., vehicle‑first vs rectangle‑first group) would not correctly represent the order in which each task was encountered, so a trial‑level coding was used instead.

# %%
def task_order(row):
    if row['order'] == 'vehicle_first' and row['task'] == 'vehicle':
        return 1
    if row['order'] == 'vehicle_first' and row['task'] == 'rectangle':
        return 2
    if row['order'] == 'rectangle_first' and row['task'] == 'rectangle':
        return 1
    if row['order'] == 'rectangle_first' and row['task'] == 'vehicle':
        return 2
    return np.nan

long['task_order'] = long.apply(task_order, axis=1)
long['task_order'] = long['task_order'].astype(int)

# %%
#display long sorted by id
display(long.sort_values(by='id'))
# Out:
#       id  gender            order expertise_programming  \
# 216    1    male    vehicle_first                  high
# 0      1    male    vehicle_first                  high
# 1      2    male  rectangle_first                medium
# 217    2    male  rectangle_first                medium
# 218    3  female    vehicle_first                  none
# ..   ...     ...              ...                   ...
# 429  214    male  rectangle_first                medium
# 214  215    male    vehicle_first                medium
# 430  215    male    vehicle_first                medium
# 431  216  female    vehicle_first                  none
# 215  216  female    vehicle_first                  none
#
#     expertise_experiment_language  time_programming english_level       task  \
# 216                          high              40.0          high    vehicle
# 0                            high              40.0          high  rectangle
# 1                          medium               5.0        medium  rectangle
# 217                        medium               5.0        medium    vehicle
# 218                          none               0.0          high    vehicle
# ..                            ...               ...           ...        ...
# 429                        medium               4.0          high    vehicle
# 214                        medium               2.0        medium  rectangle
# 430                        medium               2.0        medium    vehicle
# 431                          none               0.0          high    vehicle
# 215                          none               0.0          high  rectangle
#
#      correct  gender_bin  expertise_programming_num  expertise_experiment_num  \
# 216        0           0                          3                         3
# 0          1           0                          3                         3
# 1          0           0                          2                         2
# 217        0           0                          2                         2
# 218        0           1                          0                         0
# ..       ...         ...                        ...                       ...
# 429        1           0                          2                         2
# 214        0           0                          2                         2
# 430        1           0                          2                         2
# 431        0           1                          0                         0
# 215        1           1                          0                         0
#
#      english_bin  task_order
# 216            1           1
# 0              1           2
# 1              0           1
# 217            0           2
# 218            1           1
# ..           ...         ...
# 429            1           2
# 214            0           2
# 430            0           1
# 431            1           1
# 215            1           2
#
# [432 rows x 14 columns]

# %%
# Count participants with high English proficiency (english_bin = 1) and non-high proficiency (english_bin = 0).
# There are two task rows per participant, so divide by 2.
long['english_bin'].value_counts()/2
# Out:
# english_bin
# 1    123.0
# 0     93.0
# Name: count, dtype: float64

# %%
#long[long['time_programming'] >= 40]

# %%
#long['time_programming'].describe()

# %%
# Prepare numeric predictors for VIF, dropping any remaining NaNs if present after explicit conversion

vif_df = long[['id','expertise_programming_num','expertise_experiment_num','english_bin','time_programming']].drop_duplicates('id').drop(columns='id') #there are two rows per participant- only one needed
vif_df = vif_df[['expertise_programming_num','expertise_experiment_num','english_bin','time_programming']].dropna()

# Add constant for VIF calculation
X = sm.add_constant(vif_df)

vifs = pd.Series(
    [variance_inflation_factor(X.values, i+1) for i in range(X.shape[1]-1)],  # skip const
    index=['expertise_programming_num','expertise_experiment_num','english_bin','time_programming']
)
print("\nVIFs:\n", vifs)

# Correlation matrix
print("\nCorrelation matrix:\n")
display(vif_df.corr())
# Out:
# VIFs:
#  expertise_programming_num    2.172509
# expertise_experiment_num     1.780160
# english_bin                  1.002032
# time_programming             1.342864
# dtype: float64
#
# Correlation matrix:
#                            expertise_programming_num  \
# expertise_programming_num                   1.000000
# expertise_experiment_num                    0.660210
# english_bin                                 0.029118
# time_programming                            0.502780
#
#                            expertise_experiment_num  english_bin  \
# expertise_programming_num                  0.660210     0.029118
# expertise_experiment_num                   1.000000     0.042682
# english_bin                                0.042682     1.000000
# time_programming                           0.295277     0.025466
#
#                            time_programming
# expertise_programming_num          0.502780
# expertise_experiment_num           0.295277
# english_bin                        0.025466
# time_programming                   1.000000

# %% [markdown]
# Before running the regression model, I examined whether any of the predictors were too similar to each other, which can distort model estimates.
#
# Multicollinearity diagnostics were conducted using both the Variance Inflation Factor (VIF) and a Pearson correlation matrix. All predictors showed VIF values well below the commonly accepted threshold of 5 (expertise in programming: 2.17; expertise in experiment language: 1.78; English proficiency: 1.00; time spent programming: 1.34).
#
# The correlation matrix further supported this conclusion. Although programming expertise was moderately correlated with experiment‑language expertise (r = 0.66) and time spent programming (r = 0.50), these relationships did not reach levels typically considered problematic. All other correlations were weak (r < 0.30).

# %% [markdown]
# English proficiency was included as a binary predictor comparing high proficiency with non-high proficiency. Participants with medium or low English proficiency were grouped together because only four participants reported low proficiency, making a separate low-English category too sparse for stable estimation. The distribution was 123 high-proficiency participants and 93 non-high participants (89 medium and 4 low), and VIF values indicated no multicollinearity (VIF = 1.00). Therefore, the English coefficient should be interpreted as the association between high English proficiency and correctness relative to all non-high English proficiency participants.

# %%
# Primary formula: population-average model accounting for repeated measures
formula = "correct ~ gender_bin + expertise_programming_num + expertise_experiment_num + english_bin + C(task) + task_order"

model_gee = GEE.from_formula(formula, groups="id", data=long, family=Binomial(), cov_struct=Exchangeable())
result_gee = model_gee.fit()
print(result_gee.summary())
# Out:
#                                GEE Regression Results
# ===================================================================================
# Dep. Variable:                     correct   No. Observations:                  432
# Model:                                 GEE   No. clusters:                      216
# Method:                        Generalized   Min. cluster size:                   2
#                       Estimating Equations   Max. cluster size:                   2
# Family:                           Binomial   Mean cluster size:                 2.0
# Dependence structure:         Exchangeable   Num. iterations:                     5
# Date:                     Sun, 28 Jun 2026   Scale:                           1.000
# Covariance type:                    robust   Time:                         02:00:28
# =============================================================================================
#                                 coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# Intercept                    -0.3562      0.502     -0.709      0.478      -1.341       0.628
# C(task)[T.vehicle]           -2.1411      0.232     -9.225      0.000      -2.596      -1.686
# gender_bin                   -0.1230      0.277     -0.443      0.658      -0.667       0.421
# expertise_programming_num     0.4421      0.207      2.140      0.032       0.037       0.847
# expertise_experiment_num      0.0120      0.175      0.068      0.945      -0.332       0.356
# english_bin                   0.3934      0.217      1.811      0.070      -0.032       0.819
# task_order                    0.1377      0.226      0.610      0.542      -0.305       0.580
# ==============================================================================
# Skew:                          0.0929   Kurtosis:                      -0.7583
# Centered skew:                 0.0000   Centered kurtosis:             -0.4041
# ==============================================================================

# %% [markdown]
# We used a population-averaged generalized estimating equation (GEE) logistic model to examine whether gender predicts code comprehension accuracy, while accounting for within-subject correlation across tasks and controlling for expertise, task difficulty, and order effects.
#
# Programming expertise was coded as an ordinal numeric predictor (`none = 0`, `low = 1`, `medium = 2`, `high = 3`). This treats the self-reported expertise categories as an ordered scale and assumes that each one-level increase has a constant association with the log-odds of a correct response. This coding was used to preserve model parsimony and reflect the ordinal nature of the variable. However, the distances between self-reported categories may not be equal, so the expertise coefficient should be interpreted as an average linear trend across expertise levels rather than as a precise comparison between any two specific categories.

# %% [markdown]
# In statsmodels, the baseline category for a categorical variable is the first category in the variable’s defined order. Because the task variable was coded with rectangle as the first category, it served as the reference level in the GEE model.

# %%
formula = "correct ~ gender_bin + expertise_programming_num + C(task) + task_order"

model_gee = GEE.from_formula(formula, groups="id", data=long, family=Binomial(), cov_struct=Exchangeable())
result_gee = model_gee.fit()
print(result_gee.summary())
# Out:
#                                GEE Regression Results
# ===================================================================================
# Dep. Variable:                     correct   No. Observations:                  432
# Model:                                 GEE   No. clusters:                      216
# Method:                        Generalized   Min. cluster size:                   2
#                       Estimating Equations   Max. cluster size:                   2
# Family:                           Binomial   Mean cluster size:                 2.0
# Dependence structure:         Exchangeable   Num. iterations:                     5
# Date:                     Sun, 28 Jun 2026   Scale:                           1.000
# Covariance type:                    robust   Time:                         02:00:28
# =============================================================================================
#                                 coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# Intercept                    -0.1791      0.476     -0.376      0.707      -1.113       0.755
# C(task)[T.vehicle]           -2.1228      0.230     -9.237      0.000      -2.573      -1.672
# gender_bin                   -0.0483      0.278     -0.174      0.862      -0.594       0.497
# expertise_programming_num     0.4657      0.156      2.979      0.003       0.159       0.772
# task_order                    0.1362      0.224      0.609      0.543      -0.302       0.575
# ==============================================================================
# Skew:                          0.1091   Kurtosis:                      -0.7601
# Centered skew:                 0.0000   Centered kurtosis:             -0.4084
# ==============================================================================

# %% [markdown]
# To evaluate whether additional background variables altered the main inference, two GEE models were compared. The focused model included the predictors required to answer the research question: gender, programming expertise, task type, and trial-level task order. The expanded model added two further predictors: experiment-language expertise and English proficiency.
#
# Experiment-language expertise reflects how familiar participants were with the specific programming language used in the tasks. Its coefficient was extremely small and non-significant (p = .945), suggesting little additional association with accuracy once general programming expertise was included.
#
# English proficiency was included as a high-versus-non-high contrast, where the non-high group combined medium and low proficiency participants because only four participants reported low English proficiency. Although the coefficient was positive, suggesting that high-proficiency participants might perform slightly better than non-high participants, this contrast did not reach statistical significance (p = .070).
#
# Adding these two predictors did not change the interpretation of the primary variables of interest. In both models, gender remained non-significant, programming expertise remained a positive predictor, and the vehicle task remained substantially more difficult than the rectangle task. Task order also remained non-significant in both models.
#
# Because the additional predictors were not central to the research question and did not alter the main interpretation, the focused model was retained as the final model. This provides a more parsimonious adjusted analysis while still controlling for the key factors relevant to the research question.

# %%
params = result_gee.params
conf = result_gee.conf_int()
or_series = np.exp(params)
ci_lower = np.exp(conf[0])
ci_upper = np.exp(conf[1])

summary_or = pd.DataFrame({
    'coef': params,
    'OR': or_series,
    'CI_lower': ci_lower,
    'CI_upper': ci_upper,
    'pvalue': result_gee.pvalues
})

# Round for readability
print("\nPopulation-average Odds Ratios (GEE):\n", summary_or.round(4))
# Out:
# Population-average Odds Ratios (GEE):
#                               coef      OR  CI_lower  CI_upper  pvalue
# Intercept                 -0.1791  0.8360    0.3286    2.1267  0.7069
# C(task)[T.vehicle]        -2.1228  0.1197    0.0763    0.1878  0.0000
# gender_bin                -0.0483  0.9528    0.5522    1.6441  0.8622
# expertise_programming_num  0.4657  1.5931    1.1727    2.1643  0.0029
# task_order                 0.1362  1.1459    0.7391    1.7767  0.5427

# %% [markdown]
# A population-average logistic regression model using generalized estimating equations (GEE) was fitted to predict comprehension accuracy while accounting for repeated measures across tasks.

# %% [markdown]
# The population-average odds ratios from the GEE model provide an intuitive interpretation of each predictor's association with the likelihood of answering a comprehension question correctly. Task type showed the strongest association: the odds of a correct response on the vehicle task were only 12% of the odds on the rectangle task (OR = 0.12, 95% CI [0.08, 0.19], p < .001), confirming that the vehicle task was substantially more difficult. Programming expertise was also a significant positive predictor, with each one-unit increase in expertise associated with a 59% increase in the odds of answering correctly (OR = 1.59, 95% CI [1.17, 2.16], p = .003). The estimated gender association was close to null and not statistically significant (female relative to male: OR = 0.95, 95% CI [0.55, 1.64], p = .862). This indicates no detectable adjusted association between gender and accuracy in this sample, rather than proving that no gender effect exists. Task order likewise showed no significant effect (OR = 1.15, 95% CI [0.74, 1.78], p = .543), suggesting no detectable learning or fatigue effect in this model.

# %%
# Create a reproducible interpretation table for the focused GEE model.
predictor_order = [
    'gender_bin',
    'C(task)[T.vehicle]',
    'expertise_programming_num',
    'task_order'
]

predictor_labels = {
    'gender_bin': 'Gender (female vs male)',
    'C(task)[T.vehicle]': 'Task (Vehicle vs Rectangle)',
    'expertise_programming_num': 'Programming expertise',
    'task_order': 'Task order (second vs first)'
}

interpretations = {
    'gender_bin': 'No detectable adjusted gender association',
    'C(task)[T.vehicle]': 'Vehicle had substantially lower odds of a correct response',
    'expertise_programming_num': 'Higher expertise was associated with higher odds of correctness',
    'task_order': 'No detectable learning or fatigue effect'
}

def format_p_value(p_value):
    return '< .001' if p_value < 0.001 else f'{p_value:.3f}'

gee_interpretation_table = summary_or.loc[predictor_order, ['OR', 'CI_lower', 'CI_upper', 'pvalue']].copy()
gee_interpretation_table['Predictor'] = gee_interpretation_table.index.map(predictor_labels)
gee_interpretation_table['OR'] = gee_interpretation_table['OR'].map(lambda value: f'{value:.2f}')
gee_interpretation_table['95% CI'] = gee_interpretation_table.apply(
    lambda row: f"[{row['CI_lower']:.2f}, {row['CI_upper']:.2f}]", axis=1
)
gee_interpretation_table['p'] = gee_interpretation_table['pvalue'].map(format_p_value)
gee_interpretation_table['Interpretation'] = gee_interpretation_table.index.map(interpretations)
gee_interpretation_table = gee_interpretation_table[
    ['Predictor', 'OR', '95% CI', 'p', 'Interpretation']
].set_index('Predictor')

display(
    gee_interpretation_table.style
    .set_uuid('rq1_gee_interpretation')
    .set_caption('Focused GEE model interpretation')
    .set_properties(**{'text-align': 'left', 'white-space': 'normal'})
    .set_table_styles([
        {'selector': 'caption', 'props': [('caption-side', 'top'), ('font-weight', 'bold'), ('font-size', '14px')]},
        {'selector': 'th', 'props': [('text-align', 'left'), ('font-weight', 'bold')]},
        {'selector': 'td', 'props': [('padding', '8px 12px')]},
    ])
)
# Out:
# <style type="text/css">
# #T_rq1_gee_interpretation caption {
#   caption-side: top;
#   font-weight: bold;
#   font-size: 14px;
# }
# #T_rq1_gee_interpretation th {
#   text-align: left;
#   font-weight: bold;
# }
# #T_rq1_gee_interpretation td {
#   padding: 8px 12px;
# }
# #T_rq1_gee_interpretation_row0_col0, #T_rq1_gee_interpretation_row0_col1, #T_rq1_gee_interpretation_row0_col2, #T_rq1_gee_interpretation_row0_col3, #T_rq1_gee_interpretation_row1_col0, #T_rq1_gee_interpretation_row1_col1, #T_rq1_gee_interpretation_row1_col2, #T_rq1_gee_interpretation_row1_col3, #T_rq1_gee_interpretation_row2_col0, #T_rq1_gee_interpretation_row2_col1, #T_rq1_gee_interpretation_row2_col2, #T_rq1_gee_interpretation_row2_col3, #T_rq1_gee_interpretation_row3_col0, #T_rq1_gee_interpretation_row3_col1, #T_rq1_gee_interpretation_row3_col2, #T_rq1_gee_interpretation_row3_col3 {
#   text-align: left;
#   white-space: normal;
# }
# </style>
# <table id="T_rq1_gee_interpretation" class="dataframe">
#   <caption>Focused GEE model interpretation</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_rq1_gee_interpretation_level0_col0" class="col_heading level0 col0" >OR</th>
#       <th id="T_rq1_gee_interpretation_level0_col1" class="col_heading level0 col1" >95% CI</th>
#       <th id="T_rq1_gee_interpretation_level0_col2" class="col_heading level0 col2" >p</th>
#       <th id="T_rq1_gee_interpretation_level0_col3" class="col_heading level0 col3" >Interpretation</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Predictor</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_rq1_gee_interpretation_level0_row0" class="row_heading level0 row0" >Gender (female vs male)</th>
#       <td id="T_rq1_gee_interpretation_row0_col0" class="data row0 col0" >0.95</td>
#       <td id="T_rq1_gee_interpretation_row0_col1" class="data row0 col1" >[0.55, 1.64]</td>
#       <td id="T_rq1_gee_interpretation_row0_col2" class="data row0 col2" >0.862</td>
#       <td id="T_rq1_gee_interpretation_row0_col3" class="data row0 col3" >No detectable adjusted gender association</td>
#     </tr>
#     <tr>
#       <th id="T_rq1_gee_interpretation_level0_row1" class="row_heading level0 row1" >Task (Vehicle vs Rectangle)</th>
#       <td id="T_rq1_gee_interpretation_row1_col0" class="data row1 col0" >0.12</td>
#       <td id="T_rq1_gee_interpretation_row1_col1" class="data row1 col1" >[0.08, 0.19]</td>
#       <td id="T_rq1_gee_interpretation_row1_col2" class="data row1 col2" >< .001</td>
#       <td id="T_rq1_gee_interpretation_row1_col3" class="data row1 col3" >Vehicle had substantially lower odds of a correct response</td>
#     </tr>
#     <tr>
#       <th id="T_rq1_gee_interpretation_level0_row2" class="row_heading level0 row2" >Programming expertise</th>
#       <td id="T_rq1_gee_interpretation_row2_col0" class="data row2 col0" >1.59</td>
#       <td id="T_rq1_gee_interpretation_row2_col1" class="data row2 col1" >[1.17, 2.16]</td>
#       <td id="T_rq1_gee_interpretation_row2_col2" class="data row2 col2" >0.003</td>
#       <td id="T_rq1_gee_interpretation_row2_col3" class="data row2 col3" >Higher expertise was associated with higher odds of correctness</td>
#     </tr>
#     <tr>
#       <th id="T_rq1_gee_interpretation_level0_row3" class="row_heading level0 row3" >Task order (second vs first)</th>
#       <td id="T_rq1_gee_interpretation_row3_col0" class="data row3 col0" >1.15</td>
#       <td id="T_rq1_gee_interpretation_row3_col1" class="data row3 col1" >[0.74, 1.78]</td>
#       <td id="T_rq1_gee_interpretation_row3_col2" class="data row3 col2" >0.543</td>
#       <td id="T_rq1_gee_interpretation_row3_col3" class="data row3 col3" >No detectable learning or fatigue effect</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Interaction model to test whether gender effect differs by task
formula_int = "correct ~ gender_bin * C(task) + expertise_programming_num + task_order"
#formula_int = "correct ~ gender_bin * C(task) + expertise_programming_num + expertise_experiment_num + english_bin + task_order"
model_gee_int = GEE.from_formula(formula_int, groups="id", data=long, family=Binomial(), cov_struct=Exchangeable())
res_int = model_gee_int.fit()
print(res_int.summary())

# Odds ratios for interaction model
params_int = res_int.params
conf_int = res_int.conf_int()
or_int = np.exp(params_int)
ci_lower_int = np.exp(conf_int[0])
ci_upper_int = np.exp(conf_int[1])
pd.DataFrame({'coef':params_int,'OR':or_int,'CI_lower':ci_lower_int,'CI_upper':ci_upper_int,'pvalue':res_int.pvalues}).round(4)
# Out:
#                                GEE Regression Results
# ===================================================================================
# Dep. Variable:                     correct   No. Observations:                  432
# Model:                                 GEE   No. clusters:                      216
# Method:                        Generalized   Min. cluster size:                   2
#                       Estimating Equations   Max. cluster size:                   2
# Family:                           Binomial   Mean cluster size:                 2.0
# Dependence structure:         Exchangeable   Num. iterations:                     5
# Date:                     Sun, 28 Jun 2026   Scale:                           1.000
# Covariance type:                    robust   Time:                         02:00:28
# =================================================================================================
#                                     coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# Intercept                        -0.2525      0.483     -0.522      0.601      -1.200       0.695
# C(task)[T.vehicle]               -1.9992      0.248     -8.058      0.000      -2.485      -1.513
# gender_bin                        0.2593      0.391      0.662      0.508      -0.508       1.026
# gender_bin:C(task)[T.vehicle]    -0.7379      0.631     -1.169      0.242      -1.975       0.499
# expertise_programming_num         0.4719      0.158      2.982      0.003       0.162       0.782
# task_order                        0.1377      0.224      0.616      0.538      -0.301       0.576
# ==============================================================================
# Skew:                          0.1014   Kurtosis:                      -0.7634
# Centered skew:                 0.0000   Centered kurtosis:             -0.4092
# ==============================================================================
#                                  coef      OR  CI_lower  CI_upper  pvalue
# Intercept                     -0.2525  0.7769    0.3013    2.0029  0.6013
# C(task)[T.vehicle]            -1.9992  0.1354    0.0833    0.2202  0.0000
# gender_bin                     0.2593  1.2960    0.6018    2.7911  0.5077
# gender_bin:C(task)[T.vehicle] -0.7379  0.4781    0.1387    1.6477  0.2424
# expertise_programming_num      0.4719  1.6031    1.1755    2.1862  0.0029
# task_order                     0.1377  1.1476    0.7404    1.7787  0.5380

# %% [markdown]
# To examine whether the adjusted gender association varied across the two task types, an interaction model including a gender x task term was fitted. The interaction was not significant (OR = 0.48, 95% CI [0.14, 1.65], p = .242), providing no evidence that the gender association differed between the rectangle and vehicle tasks. Gender was also non-significant on the baseline task (OR = 1.30, p = .508), and the vehicle task remained substantially more difficult (OR = 0.14, p < .001). Programming expertise continued to be a positive predictor of accuracy, and task order remained non-significant. Because the interaction did not alter the interpretation of the main predictors, the simpler main-effects model was retained as the final model.

# %% [markdown]
# Although the female subgroup was smaller than the male subgroup (41 vs. 175 participants), the estimated gender odds ratio was close to 1. However, the 95% confidence interval was relatively wide (OR = 0.95, 95% CI [0.55, 1.64]). This interval is compatible with effects in either direction, so the result should be interpreted as a lack of detectable adjusted evidence for a gender association in this sample, not as evidence that gender effects are impossible or definitively negligible.

# %% [markdown]
# The gender groups were imbalanced (41 females vs. 175 males), which limits power to detect small or uncertain gender associations. The model detected strong task and programming-expertise associations, but that does not by itself establish adequate power for the between-subject gender comparison. A formal power or sensitivity analysis would be needed to quantify the smallest gender effect this dataset could reliably detect. Therefore, the safest interpretation is that the estimated adjusted gender association was close to null and non-significant, while subtle effects cannot be ruled out.

# %% [markdown]
# # Plots for GEE

# %%
# Create a balanced prediction grid using common covariate values for both gender groups
mean_expertise = long['expertise_programming_num'].mean()
mean_task_order = long['task_order'].mean()

plot_df = pd.DataFrame([
    {
        'gender_bin': g,
        'expertise_programming_num': mean_expertise,
        'task': t,
        'task_order': mean_task_order
    }
    for g in [0, 1] for t in ['rectangle', 'vehicle']
])
plot_df['task'] = pd.Categorical(plot_df['task'], categories=['rectangle', 'vehicle'])
plot_df['predicted'] = result_gee.predict(plot_df)
plot_df['gender'] = plot_df['gender_bin'].map({0: 'Male', 1: 'Female'})

sns.pointplot(data=plot_df, x='task', y='predicted', hue='gender', dodge=True, markers='o', capsize=.1)
plt.ylabel("Predicted Probability of Correct Answer")
plt.xlabel("Task Type")
plt.title("Adjusted Predicted Accuracy by Gender x Task (GEE Model)")
plt.ylim(0, 1)
plt.show()

# %%
# Prepare OR table
or_df = summary_or.reset_index().rename(columns={'index':'predictor'})

# Remove intercept for clarity
or_df = or_df[or_df['predictor'] != 'Intercept']

plt.figure(figsize=(8,5))
sns.pointplot(data=or_df, y='predictor', x='OR', join=False)
plt.errorbar(or_df['OR'], or_df['predictor'],
             xerr=[or_df['OR'] - or_df['CI_lower'], or_df['CI_upper'] - or_df['OR']],
             fmt='none', c='black', capsize=3)

plt.axvline(1, color='red', linestyle='--')
plt.xlabel("Odds Ratio (log scale recommended)")
plt.title("Odds Ratios with 95% CI (GEE Model)")
plt.xscale('log')
plt.show()
# Out:
# /tmp/ipykernel_11650/2937383275.py:8: UserWarning:
#
# The `join` parameter is deprecated and will be removed in v0.15.0. You can remove the line between points with `linestyle='none'`.
#
#   sns.pointplot(data=or_df, y='predictor', x='OR', join=False)

# %%
# Build prediction grid using the mean observed task-order value
expertise_vals = sorted(long['expertise_programming_num'].dropna().unique())
expertise_labels = {
    0: "None",
    1: "Low",
    2: "Medium",
    3: "High"
}
mean_task_order = long['task_order'].mean()

grid = pd.DataFrame([
    {'gender_bin': g, 'expertise_programming_num': e, 'task': t, 'task_order': mean_task_order}
    for g in [0, 1] for e in expertise_vals for t in ['rectangle', 'vehicle']
])
grid['task'] = pd.Categorical(grid['task'], categories=['rectangle', 'vehicle'])
grid['expertise_label'] = grid['expertise_programming_num'].map(expertise_labels)
grid['expertise_label'] = pd.Categorical(grid['expertise_label'], categories=['None', 'Low', 'Medium', 'High'], ordered=True)
grid['gender'] = grid['gender_bin'].map({0: 'Male', 1: 'Female'})

# Predict probabilities
grid['pred_prob'] = result_gee.predict(grid)

# Plot predicted probabilities by expertise and gender for each task
sns.set(style="whitegrid")
g = sns.FacetGrid(grid, col="task", height=4, sharey=True)
g.map_dataframe(sns.lineplot, x='expertise_label', y='pred_prob', hue='gender', marker='o')
g.add_legend(title='Gender')
g.set_axis_labels("Programming expertise (ordinal)", "Predicted probability correct")
plt.show()

# %% [markdown]
# Percentages within gender-by-expertise subgroups should be interpreted descriptively because some cells are small, especially the female high-expertise group (`n = 4`). In these small subgroups, a single participant can substantially change the plotted percentage.

# %% [markdown]
# By including programming expertise as a covariate, the analysis adjusts the estimated gender association for self-reported skill, task type, and task order. This is an adjusted comparison rather than exact matching between male and female participants. Under this model, gender was not a statistically significant predictor of comprehension accuracy, whereas programming expertise was. This pattern is consistent with a skill-gap account in which differences in prior programming experience may contribute to raw performance differences, but the observational design and self-reported expertise measure mean it should not be interpreted as causal evidence that expertise fully explains gender differences. Although more complex models (e.g., GLMMs with random intercepts) could be used to model individual baseline differences, the current GEE analysis addresses the central adjusted association: whether gender predicts accuracy after accounting for expertise and task conditions.

# %% [markdown]
# Across the fitted models and visualizations, gender did not significantly predict comprehension accuracy once programming expertise and task type were controlled. Expertise was a positive predictor, and the vehicle task was substantially more difficult than the rectangle task. These results suggest that the observed data do not provide evidence of an adjusted gender difference in accuracy, but they do not prove that gender has no effect or that expertise and task difficulty fully explain all possible gender-related differences.
